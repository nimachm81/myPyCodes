# %%
### check reuiters

from Finance.Finance import CompanyNews

cn = CompanyNews(60)

cn.getReutersCompanyNews()
# Out:
# feed[ "bozo" ]:  0
# feed[ "url" ]:  http://feeds.reuters.com/reuters/companyNews?format=xml
# feed[ "version" ]:  rss20
# feed[ "channel" ]:  dict_keys(['subtitle_detail', 'image', 'feedburner_info', 'links', 'subtitle', 'rights', 'updated_parsed', 'link', 'language', 'rights_detail', 'updated', 'title', 'title_detail'])
# feed[ "items" ]:  10
# 1  :  BRIEF-Medovex corporation receives CE mark approval for Denervex system
# 2  :  BRIEF-SentinelOne joins Fortinet's Fabric-Ready program
# 3  :  BRIEF-Nokia files preliminary prospectus supplement with U.S. SEC for potential two-part notes offering
# 4  :  BRIEF-Alphamin Resources announces equity fundraising of up to $38 mln
# 5  :  BRIEF-UPS says opens new healthcare facility in Colombia
# 6  :  BRIEF-Amgen submits regulatory applications for repatha cardiovascular outcomes data in US, Europe
# 7  :  BRIEF-True North Commercial REIT continues urban growth with $53.6 mln property acquisitions in GTA, Ottawa And Victoria
# ...
