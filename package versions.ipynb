# %%
import subprocess
p = subprocess.Popen(['pip3', 'freeze'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
out, err = p.communicate()
print(out.decode('utf-8'))
# Out:
# Brlapi==0.6.1
# Jinja2==2.8
# LibAppArmor==2.8.95
# Magic-file-extensions==0.2
# Mako==0.9.1
# MarkupSafe==0.18
# MeshPy==2014.1
# PyOpenGL==3.1.0
# PyOpenGL-accelerate==3.1.0
# PyPDF2==1.24
# PyVTK==0.5.18
# PyYAML==3.11
# Pygments==2.0.2
# Send2Trash==1.3.0
# apparmor==2.8.95
# apparmor.click==0.2ubuntu1
# appdirs==1.4.0
# apturl==0.5.2ubuntu4
# beautifulsoup4==4.2.1
# certifi==14.05.14
# chardet==2.2.1
# checkbox-ng==0.3
# checkbox-support==0.2
# click==0.4.21.1ubuntu0.2
# colorama==0.2.5
# command-not-found==0.3
# cycler==0.10.0
# deap==1.0.1
# decorator==3.4.0
# defer==1.0.6
# devscripts==2.14.1ubuntu0.1
# feedparser==5.1.3
# friends==0.1
# google-api-python-client==1.4.1
# html5lib==0.999
# httplib2==0.9.2
# ipykernel==4.1.1
# ipyparallel==4.1.0
# ipython==4.0.0
# ipython-genutils==0.1.0
# ipywidgets==4.1.1
# jsonschema==2.5.1
# jupyter==1.0.0
# jupyter-client==4.1.1
# jupyter-console==4.0.3
# jupyter-core==4.0.6
# language-selector==0.1
# louis==2.5.3
# lxml==3.3.3
# ...
